# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %matplotlib inline

import pprint
import trainer

explored_parameters = {}
for i in range(10):
    parameters = trainer.gen_all_parameters()
    results = []
    print str(i)
    pprint.pprint(parameters)
    for _ in range(10):
        results.append(trainer.train(n_epochs=500, **parameters))
    import matplotlib.pyplot as plt
    plt.figure(figsize=(10,10))
    plt.hist([r['reward'] for r in results])
    plt.title(str(parameters))
    plt.show()
    #explored_parameters[str(parameters)] = results
#print "Graphing"
#for parameters, results in explored_parameters.iteritems():
#    import matplotlib.pyplot as plt

#    pprint.pprint(parameters)
#    plt.hist([r['reward'] for r in results])
#    plt.title(str(parameters))
#    plt.show()
# Out:
# [2017-12-27 20:16:19,070] Making new env: Pendulum-v0
# 0
# {'agent_params': {'learning': {'learning_rate': 0.0005},
#                   'network': {'hidden_layers': [200, 200, 200],
#                               'nonlinearity': <function tanh at 0x7f58b18a61b8>}},
#  'critic_params': {'learning': {'learning_rate': 0.0005},
#                    'network': {'hidden_layers': [200, 200, 200],
#                                'nonlinearity': <function relu at 0x7f58b1760488>}},
#  'explore_params': {'decay': 0, 'scale': 0.5}}
# Epoch 0 Reward -2638.97341038

# %%
from matplotlib import pyplot as plt
plt.figure(figsize=(10,10))
x = [1,2,3]
plt.plot(x, x)
plt.show()
